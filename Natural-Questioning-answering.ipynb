# %%
# Import Libraries
import os
from torch.utils.data import DataLoader, Dataset
from transformers import (
    DistilBertForSequenceClassification,
    BertForQuestionAnswering,
    AdamW,
    BertForSequenceClassification,
    AutoTokenizer
)
import torch
from torch.nn.utils.rnn import pad_sequence
from tqdm import tqdm
from sklearn.metrics import classification_report, accuracy_score
import gzip
import json
import random
from collections import defaultdict, Counter
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
import shutil
from torch.cuda.amp import GradScaler, autocast

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Function to clear up
# "balanced_yes_no_data.json", "test_data.json", "train_data.json", "val_data.json", "fine_tuned_bert_yes_no_model"
paths_to_clear = ["fine_tuned_bert_short_answer_model", "balanced_yes_no_data.json", "test_data.json", "train_data.json", "val_data.json", "fine_tuned_bert_long_answer_model"]

for path in paths_to_clear:
    if os.path.exists(path):
        if os.path.isdir(path):
            shutil.rmtree(path)
            print(f"Deleted directory: {path}")
        elif os.path.isfile(path):
            os.remove(path)
            print(f"Deleted file: {path}")
    else:
        print(f"Path not found: {path}")
# Out:
# Path not found: fine_tuned_bert_short_answer_model
# Deleted file: balanced_yes_no_data.json
# Path not found: test_data.json
# Path not found: train_data.json
# Path not found: val_data.json
# Path not found: fine_tuned_bert_long_answer_model

# %% [markdown]
# Here is the code section for processing Yes/No questions: This part handles tasks related to binary classification, such as determining "YES" or "NO" answers based on input data.

# %%
# Function to Clean HTML
def clean_html(text):
    return BeautifulSoup(text, "html.parser").get_text()
print("clean_html function defined.")

# Function to Process Files for yes or no qa
def process_file(file_path, output_data):
    oversized_long_answer_count = 0 
    excluded_examples = 0
    max_context_length = 400

    with gzip.open(file_path, 'rt', encoding='utf-8') as file:
        for i, line in enumerate(file):
            example = json.loads(line)
            question = example['question_text']
            document = example['document_text']
            annotations = example.get('annotations', [])

            if annotations and annotations[0]['yes_no_answer'] != "NONE":
                yes_no_answer = annotations[0]['yes_no_answer']
                long_answer = annotations[0].get('long_answer', {})
                short_answer = annotations[0].get('short_answers', [])
                start_token = long_answer.get("start_token")
                end_token = long_answer.get("end_token")

                if start_token is not None and end_token is not None:
                    span_length = end_token - start_token
                    if span_length > 1000:
                        oversized_long_answer_count += 1

                        if short_answer:
                            end_token = short_answer[0]["end_token"]
                            print(f"Using short answer for oversized long answer. Question: {question}")
                        else:
                            excluded_examples += 1
                            print(f"Excluding example. Question: {question}, Span Length: {span_length}")
                            continue

                cleaned_document = clean_html(document)

                context = " ".join(cleaned_document.split()[start_token:end_token]) if start_token and end_token else cleaned_document
                if len(context.split()) > max_context_length:
                    excluded_examples += 1
                    print(f"Excluding example due to context length > {max_context_length}. Question: {question}")
                    continue

                output_data["yes_no"].append({
                    "type": "yes_no",
                    "question": question,
                    "document": context,
                    "yes_no_answer": yes_no_answer
                })

    print(f"File {file_path} processed.")
    print(f"  Oversized long answers handled: {oversized_long_answer_count}")
    print(f"  Excluded examples: {excluded_examples}")

print("process_file function defined.")
# Out:
# clean_html function defined.
# process_file function defined.

# %%
# Process Dataset and Balance Yes/No Data
input_folder = "simplified_natural_questions"
output_data = defaultdict(list)

all_files = [file for file in os.listdir(input_folder) if file.endswith(".jsonl.gz")]
print(f"Found {len(all_files)} files. Processing one file for inspection...")

num_files_to_process = 50
files_to_process = all_files[:num_files_to_process]

for file_name in files_to_process:
    file_path = os.path.join(input_folder, file_name)
    print(f"Processing file: {file_path}")
    process_file(file_path, output_data)

# Balance yes/no data
yes_no_data = output_data["yes_no"]
yes_data = [item for item in yes_no_data if item["yes_no_answer"] == "YES"]
no_data = [item for item in yes_no_data if item["yes_no_answer"] == "NO"]

# Find the smaller count between "YES" and "NO" and sample accordingly
min_count = min(len(yes_data), len(no_data))
balanced_yes_no_data = random.sample(yes_data, min_count) + random.sample(no_data, min_count)
random.shuffle(balanced_yes_no_data)

# Save only the balanced yes_no data
output_file = "balanced_yes_no_data.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(balanced_yes_no_data, f, indent=4)

print(f"Processing complete. Balanced yes/no data saved to {output_file}")

# Validation after processing
with open(output_file, "r", encoding="utf-8") as f:
    data = json.load(f)

type_counts = Counter([item["yes_no_answer"] for item in data])
print("Counts of each question type in the dataset:")
print(type_counts)
# Out:
# Found 50 files. Processing one file for inspection...
# Processing file: simplified_natural_questions/nq-train-06_simplified.jsonl.gz
# Excluding example. Question: do canadian citizens need a visa for myanmar, Span Length: 4419
# Excluding example. Question: do i need a visa for namibia from australia, Span Length: 4322
# Excluding example. Question: wii sports resort do you need motion plus, Span Length: 1436
# Excluding example. Question: does frank underwood become president in season 5, Span Length: 4324
# Excluding example. Question: in shameless do they get the house back, Span Length: 1837
# Excluding example. Question: do french citizens need a visa for south africa, Span Length: 4316
# Excluding example. Question: is it illegal to own a gun in california, Span Length: 2071
# Excluding example. Question: do i need a visa to go to uk from malaysia, Span Length: 3485
# Excluding example due to context length > 400. Question: are protestant and church of england the same
# File simplified_natural_questions/nq-train-06_simplified.jsonl.gz processed.
#   Oversized long answers handled: 8
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-16_simplified.jsonl.gz
# Excluding example. Question: do i need a visa from barbados to canada, Span Length: 3401
# Excluding example due to context length > 400. Question: can i carry a gun in new mexico
# Excluding example. Question: do canadian citizens need a visa for morocco, Span Length: 4693
# Excluding example due to context length > 400. Question: is a 2004 honda civic front wheel drive
# File simplified_natural_questions/nq-train-16_simplified.jsonl.gz processed.
#   Oversized long answers handled: 2
#   Excluded examples: 4
# Processing file: simplified_natural_questions/nq-train-05_simplified.jsonl.gz
# Excluding example. Question: do i need visa to go to indonesia from philippines, Span Length: 3402
# Excluding example. Question: is the united states part of north america, Span Length: 1154
# Excluding example due to context length > 400. Question: can you own a gun in baltimore city
# Excluding example due to context length > 400. Question: was debra winger in the movie the warriors
# Excluding example. Question: does ichigo get his soul reaper powers back, Span Length: 4109
# Excluding example. Question: yu gi oh 5ds episode 26 english dubbed, Span Length: 1580
# Excluding example. Question: is axa the biggest insurance company in the world, Span Length: 1572
# Excluding example due to context length > 400. Question: can you open carry a shotgun in virginia
# Excluding example. Question: do hong kong citizens need a visa for vietnam, Span Length: 4130
# File simplified_natural_questions/nq-train-05_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-35_simplified.jsonl.gz
# Excluding example. Question: one tree hill season 4 lucas and peyton get together, Span Length: 2478
# Excluding example. Question: do irish citizens need a visa for cambodia, Span Length: 6040
# Excluding example. Question: has there ever been a tie at the rose bowl, Span Length: 3100
# Excluding example. Question: do british citizens need a visa for ethiopia, Span Length: 4310
# Excluding example due to context length > 400. Question: does miss piggy have a star on the hollywood walk of fame
# Excluding example due to context length > 400. Question: do i need a gun permit for a shotgun
# Excluding example. Question: in season 2 do carrie and sebastian get back together, Span Length: 3038
# File simplified_natural_questions/nq-train-35_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-21_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: has tennessee ever won a national championship in basketball
# Excluding example. Question: do indian citizens need a visa to visit singapore, Span Length: 4064
# Excluding example due to context length > 400. Question: do you have to register a firearm in the state of nevada
# Excluding example. Question: do colombians need a visa to enter france, Span Length: 3297
# Excluding example. Question: do stores sell beer on christmas in georgia, Span Length: 2333
# Excluding example. Question: do i need a visa for netherlands from new zealand, Span Length: 4539
# Excluding example due to context length > 400. Question: monday night football is it on regular tv
# Excluding example. Question: has anyone won who wants to be a millionaire us, Span Length: 8459
# Excluding example. Question: is there a waiting period for shotguns in california, Span Length: 2010
# Excluding example. Question: is facebook the most visited site in the world, Span Length: 1500
# Excluding example due to context length > 400. Question: can you have a handgun in your car in texas
# Excluding example. Question: do south african passport holders need visas for thailand, Span Length: 4745
# Excluding example due to context length > 400. Question: is sudan considered part of the middle east
# File simplified_natural_questions/nq-train-21_simplified.jsonl.gz processed.
#   Oversized long answers handled: 8
#   Excluded examples: 13
# Processing file: simplified_natural_questions/nq-train-22_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: is there a bbc 4 plus 1 on sky
# Excluding example due to context length > 400. Question: has anyone won the world cup back to back
# Excluding example due to context length > 400. Question: is highmark blue cross blue shield the same as anthem
# Excluding example due to context length > 400. Question: does magic still own part of the dodgers
# Excluding example. Question: does hong kong passport need visa to uk, Span Length: 3439
# Excluding example due to context length > 400. Question: will there be a 3rd season of better call saul
# Excluding example. Question: can you buy alcohol on christmas in california, Span Length: 2333
# Excluding example due to context length > 400. Question: can you own a pump action shotgun in the uk
# File simplified_natural_questions/nq-train-22_simplified.jsonl.gz processed.
#   Oversized long answers handled: 2
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-11_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: has there ever been a president from pennsylvania
# Excluding example due to context length > 400. Question: did any host nation win the world cup
# Excluding example. Question: is it legal to marry your first cousin in tennessee, Span Length: 1937
# Excluding example. Question: do uk citizens need visa to visit australia, Span Length: 4202
# Excluding example due to context length > 400. Question: flip or flop underwater flip did it sell
# Excluding example due to context length > 400. Question: do you have to register firearms in oregon
# Excluding example. Question: does jackie end up with hyde in season 8, Span Length: 3380
# File simplified_natural_questions/nq-train-11_simplified.jsonl.gz processed.
#   Oversized long answers handled: 3
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-20_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: do you need a license to open carry in wisconsin
# Excluding example due to context length > 400. Question: is costa rica a province of the us
# Excluding example. Question: does an indian need a passport to enter sri lanka, Span Length: 4218
# Excluding example due to context length > 400. Question: have the astros won a world series game
# Excluding example. Question: australian passport do i need a visa for uk, Span Length: 4953
# Excluding example. Question: has there ever been a back to back world cup winner, Span Length: 1784
# Excluding example due to context length > 400. Question: is it legal to own a skunk in colorado
# Excluding example. Question: do indian citizens need a visa for seychelles, Span Length: 4782
# Excluding example. Question: do french passport holders need a visa for australia, Span Length: 4309
# Excluding example. Question: is sri lanka a member of the commonwealth, Span Length: 2232
# File simplified_natural_questions/nq-train-20_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 10
# Processing file: simplified_natural_questions/nq-train-25_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: is there a k in the welsh alphabet
# Excluding example due to context length > 400. Question: has any president appointed 3 supreme court justices
# Excluding example due to context length > 400. Question: do you need a background check to buy a shotgun in pa
# Excluding example. Question: do chinese nationals need a visa for japan, Span Length: 4599
# Excluding example due to context length > 400. Question: is the actor who played data on the orville
# Excluding example. Question: do south african citizens need a visa for malta, Span Length: 3893
# Excluding example. Question: is spanish the second most spoken language in the world, Span Length: 1637
# Excluding example. Question: does new zealand passport need visa to thailand, Span Length: 4411
# Excluding example. Question: is the usa a member of the united nations, Span Length: 4835
# Excluding example due to context length > 400. Question: can you have a hand gun in your car in texas
# File simplified_natural_questions/nq-train-25_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 10
# Processing file: simplified_natural_questions/nq-train-01_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: did lebron and shaq play on the same team
# Excluding example. Question: do italian passport holders need a visa for new zealand, Span Length: 4419
# Excluding example. Question: does cod ghosts 360 work on xbox one, Span Length: 13198
# Excluding example. Question: can you play mario galaxy with a gamecube controller, Span Length: 3239
# Excluding example. Question: do irish citizens need a visa for france, Span Length: 6219
# Excluding example. Question: have england ever won a penalty shoot out at the world cup, Span Length: 2080
# Excluding example due to context length > 400. Question: has the men's usa soccer team ever won a world cup
# Excluding example. Question: can i buy alcohol on sunday in virginia, Span Length: 1674
# Excluding example. Question: do australian citizens need a visa for nicaragua, Span Length: 4749
# Excluding example. Question: was boston ever the capital of the us, Span Length: 1106
# Excluding example. Question: has there ever been a back to back world series winner, Span Length: 5614
# File simplified_natural_questions/nq-train-01_simplified.jsonl.gz processed.
#   Oversized long answers handled: 9
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-29_simplified.jsonl.gz
# Excluding example. Question: does morocco require a visa for us citizens, Span Length: 7631
# Excluding example. Question: does a kenyan need a visa to nigeria, Span Length: 2961
# Excluding example due to context length > 400. Question: is the navy older than the marine corps
# Excluding example. Question: do us passport holders need visa for thailand, Span Length: 7643
# Excluding example. Question: is the usa part of the eu area, Span Length: 2073
# Excluding example. Question: do british passport holders need visa for kuwait, Span Length: 4546
# Excluding example. Question: has there ever been a sweep in nba finals, Span Length: 1833
# Excluding example due to context length > 400. Question: is kevin from shameless on orange is the new black
# Excluding example due to context length > 400. Question: did michael keaton won an oscar for beetlejuice
# Excluding example. Question: do i need visa to germany from malaysia, Span Length: 4323
# File simplified_natural_questions/nq-train-29_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 10
# Processing file: simplified_natural_questions/nq-train-13_simplified.jsonl.gz
# Excluding example. Question: can i get a tattoo at 16 in south carolina, Span Length: 4892
# Excluding example due to context length > 400. Question: have italy beaten ireland in the 6 nations
# Excluding example. Question: is this the first time south africa won miss universe, Span Length: 2349
# Excluding example. Question: did the movie forrest gump win any awards, Span Length: 1186
# Excluding example. Question: does malaysian passport need visa to sri lanka, Span Length: 3493
# Excluding example. Question: do irish passport holders need a visa for oman, Span Length: 6126
# Excluding example. Question: is new zealand still part of the commonwealth, Span Length: 2173
# Excluding example due to context length > 400. Question: does pennsylvania have a stop and identify law
# Excluding example. Question: do australian citizens need a visa for bulgaria, Span Length: 4953
# File simplified_natural_questions/nq-train-13_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-44_simplified.jsonl.gz
# Excluding example. Question: does a canadian need a visa for japan, Span Length: 4227
# Excluding example. Question: has there ever been a school shooting in a christian school, Span Length: 8133
# Excluding example. Question: do uk passport holders need a visa for japan, Span Length: 4484
# Excluding example due to context length > 400. Question: is there a prize for 2 lucky stars in euromillions
# Excluding example. Question: can you get a tattoo at 17 with parental consent in georgia, Span Length: 4889
# Excluding example. Question: do you need a visa to travel to dubai from ghana, Span Length: 2911
# File simplified_natural_questions/nq-train-44_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 6
# Processing file: simplified_natural_questions/nq-train-34_simplified.jsonl.gz
# Excluding example. Question: can you get a tattoo at 16 in ma, Span Length: 4889
# Excluding example due to context length > 400. Question: has rafael nadal ever lost a french open final
# Excluding example due to context length > 400. Question: was the robot evil in lost in space
# Excluding example. Question: are all queen size beds the same size, Span Length: 1090
# Excluding example due to context length > 400. Question: the first feature film produced entirely with cgi (computer-generated imagery) was toy story
# Excluding example due to context length > 400. Question: is san francisco part of the pacific northwest
# Excluding example due to context length > 400. Question: is air china part of the star alliance
# Excluding example. Question: do carrie and sebastian get back together season 2, Span Length: 3038
# Excluding example. Question: do grocery stores sell liquor in north carolina, Span Length: 1594
# Excluding example. Question: has a french team ever won the champions league, Span Length: 2487
# Excluding example. Question: in terms of area india is the largest country, Span Length: 11114
# File simplified_natural_questions/nq-train-34_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-24_simplified.jsonl.gz
# Excluding example. Question: can you put a car engine in a truck, Span Length: 2811
# Excluding example. Question: do uk citizens need a visa for tanzania, Span Length: 4202
# Excluding example. Question: do south african passport holders need a visa for madagascar, Span Length: 4887
# File simplified_natural_questions/nq-train-24_simplified.jsonl.gz processed.
#   Oversized long answers handled: 3
#   Excluded examples: 3
# Processing file: simplified_natural_questions/nq-train-28_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: do jackie and hyde get back together season 7
# Excluding example due to context length > 400. Question: does the 1 train stop at atlantic ave
# Excluding example. Question: is there a house bigger than the white house, Span Length: 4510
# Excluding example due to context length > 400. Question: is there a new episode of bunk'd
# Excluding example. Question: is there a highway in the united states with no speed limit, Span Length: 3975
# File simplified_natural_questions/nq-train-28_simplified.jsonl.gz processed.
#   Oversized long answers handled: 2
#   Excluded examples: 5
# Processing file: simplified_natural_questions/nq-train-32_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: does nevada require background checks to buy a gun
# Excluding example due to context length > 400. Question: does stefan turn his humanity back on in season 6
# Excluding example due to context length > 400. Question: resident evil revelations 2 is it 2 player
# Excluding example. Question: do australian citizens need a visa for jordan, Span Length: 4953
# Excluding example due to context length > 400. Question: is there a season 2 of star trek discovery
# Excluding example. Question: do i need a visa for europe from singapore, Span Length: 4504
# Excluding example. Question: is queen in the rock and roll hall of fame, Span Length: 6408
# Excluding example due to context length > 400. Question: does mickey mouse have a star on the hollywood walk of fame
# Excluding example due to context length > 400. Question: have england ever lost to france world cup
# Excluding example. Question: do tigers and lions have the same number of chromosomes, Span Length: 5421
# Excluding example. Question: is italy a member of the european union, Span Length: 2125
# Excluding example. Question: do i need a visa for malaysia from south africa, Span Length: 3819
# File simplified_natural_questions/nq-train-32_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 12
# Processing file: simplified_natural_questions/nq-train-09_simplified.jsonl.gz
# Excluding example. Question: can you buy alcohol in ct on sunday, Span Length: 2333
# Excluding example. Question: is chloe sullivan in season 10 of smallville, Span Length: 4137
# Excluding example. Question: is the nile river the longest river in the world, Span Length: 5909
# Excluding example. Question: is there a dragon ball super episode today, Span Length: 5364
# Excluding example due to context length > 400. Question: has south american team won world cup in europe
# Excluding example due to context length > 400. Question: is there a second season of doctor thorne
# Excluding example. Question: will there be an eclipse in new zealand, Span Length: 19867
# Excluding example. Question: does malaysian need visa to papua new guinea, Span Length: 4307
# Excluding example. Question: is there a season 3 of fullmetal alchemist, Span Length: 10834
# Excluding example. Question: do south african citizens need a visa for indonesia, Span Length: 4887
# Excluding example. Question: can i watch cnn international in the us, Span Length: 1278
# File simplified_natural_questions/nq-train-09_simplified.jsonl.gz processed.
#   Oversized long answers handled: 9
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-00_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: do you have to register a gun in montana
# Excluding example. Question: is it illegal to talk on the phone while driving in pennsylvania, Span Length: 1841
# Excluding example. Question: do irish passport holders need a visa for israel, Span Length: 6129
# Excluding example. Question: portal 2 xbox 360 compatible with xbox one, Span Length: 16083
# Excluding example. Question: will there be a new episode of dragon ball super this week, Span Length: 13250
# Excluding example due to context length > 400. Question: do you have to show id to police in ohio
# Excluding example due to context length > 400. Question: is there an english dub of tokyo godfathers
# File simplified_natural_questions/nq-train-00_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-33_simplified.jsonl.gz
# Excluding example. Question: can you marry your first cousin in california, Span Length: 1875
# Excluding example. Question: do irish citizens need a visa for the philippines, Span Length: 6219
# Excluding example. Question: does south african need visa for south korea, Span Length: 4887
# Excluding example. Question: does a south african passport holder need a visa for australia, Span Length: 3811
# Excluding example. Question: do you need a visa to go to trinidad from jamaica, Span Length: 3228
# Excluding example. Question: can a 19 year old buy alcohol in canada, Span Length: 1296
# File simplified_natural_questions/nq-train-33_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 6
# Processing file: simplified_natural_questions/nq-train-39_simplified.jsonl.gz
# Excluding example. Question: does canadian passport need visa to saudi arabia, Span Length: 4693
# Excluding example. Question: do argentines need a visa to visit canada, Span Length: 4507
# Excluding example. Question: does halo combat evolved work on xbox 360, Span Length: 1772
# Excluding example. Question: can you download kotor 2 on xbox 360, Span Length: 2151
# Excluding example due to context length > 400. Question: are most of the religions in the united states monotheistic
# Excluding example. Question: is the band america in the rock and roll hall of fame, Span Length: 6414
# Excluding example due to context length > 400. Question: are there birds that fly at 30000 feet
# Excluding example. Question: do thai citizens need a visa for south korea, Span Length: 3068
# Excluding example. Question: has there been a depression since the great depression, Span Length: 1705
# File simplified_natural_questions/nq-train-39_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-43_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: can i have a pet skunk in california
# Excluding example. Question: can you get a tattoo at 16 in missouri, Span Length: 4889
# Excluding example due to context length > 400. Question: is it legal to have a pet skunk in michigan
# Excluding example. Question: do i need a visa for italy on an australian passport, Span Length: 3756
# Excluding example due to context length > 400. Question: do you need a permit to open carry in washington
# Excluding example. Question: can you get a tattoo at 16 in nc, Span Length: 4892
# Excluding example. Question: does an australian need a visa for fiji, Span Length: 3756
# File simplified_natural_questions/nq-train-43_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-12_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: can a 17 year old carry a gun in texas
# Excluding example due to context length > 400. Question: is it legal to carry a gun in colorado
# Excluding example. Question: call of duty games backwards compatible xbox one, Span Length: 13272
# Excluding example due to context length > 400. Question: has nigeria ever reach quarter final in world cup
# Excluding example. Question: can you buy beer on sundays in colorado, Span Length: 2333
# Excluding example. Question: do singaporeans need a visa to visit netherlands, Span Length: 5287
# Excluding example. Question: do i need a visa for israel from new zealand, Span Length: 4411
# File simplified_natural_questions/nq-train-12_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-19_simplified.jsonl.gz
# Excluding example. Question: do turkish citizens need a visa for france, Span Length: 3715
# Excluding example. Question: does a nigerian need a visa to travel to singapore, Span Length: 2403
# Excluding example. Question: do you need a visa from uk to germany, Span Length: 4167
# File simplified_natural_questions/nq-train-19_simplified.jsonl.gz processed.
#   Oversized long answers handled: 3
#   Excluded examples: 3
# Processing file: simplified_natural_questions/nq-train-23_simplified.jsonl.gz
# Excluding example. Question: do indian citizens need a visa for costa rica, Span Length: 4218
# Excluding example. Question: do chilean citizens need a visa to visit usa, Span Length: 4635
# Excluding example. Question: china is the third largest country in the world, Span Length: 11154
# Excluding example due to context length > 400. Question: legal to carry loaded gun in car in texas
# Excluding example. Question: is there a color that starts with x, Span Length: 29669
# Excluding example. Question: do canadian passport holders need visa for singapore, Span Length: 4599
# Excluding example. Question: is dominican republic part of the united nations, Span Length: 3207
# Excluding example due to context length > 400. Question: does natalie merchant still tour with 10000 maniacs
# Excluding example. Question: is iphone 6 and 6 plus battery the same, Span Length: 1586
# Excluding example. Question: do uk nationals need a visa for russia, Span Length: 4202
# Excluding example. Question: can you buy liquor in nc on sunday, Span Length: 1594
# Excluding example. Question: do australian citizens need a visa to travel to italy, Span Length: 3861
# Excluding example. Question: has any nfl football team won back to back super bowls, Span Length: 3375
# File simplified_natural_questions/nq-train-23_simplified.jsonl.gz processed.
#   Oversized long answers handled: 11
#   Excluded examples: 13
# Processing file: simplified_natural_questions/nq-train-14_simplified.jsonl.gz
# Excluding example. Question: is there a holiday in the us in august, Span Length: 1219
# Excluding example. Question: is call of duty ghosts xbox 360 compatible with xbox one, Span Length: 16213
# Excluding example. Question: is bank of america in the s&p 500, Span Length: 19358
# Excluding example due to context length > 400. Question: euromillions do you win with 2 lucky stars
# Excluding example. Question: can you buy liquor at grocery stores in washington state, Span Length: 1659
# Excluding example. Question: do french citizens need a visa for argentina, Span Length: 5338
# Excluding example due to context length > 400. Question: when was the last time vietnam qualified for the world cup
# Excluding example. Question: is the indus river the longest river in the world, Span Length: 5909
# Excluding example. Question: can you marry your first cousin in wv, Span Length: 1875
# Excluding example due to context length > 400. Question: has the usa ever won the world cup in soccer
# Excluding example due to context length > 400. Question: is england going to the round of 16
# Excluding example. Question: do canadian passport holders need a visa for kenya, Span Length: 4693
# Excluding example. Question: does a ghanaian need a visa to jamaica, Span Length: 2465
# Excluding example. Question: do canadian citizens need a visa for bolivia, Span Length: 4382
# Excluding example due to context length > 400. Question: has a cat 4 hurricane ever hit florida
# Excluding example. Question: is the king of the danes in beowulf, Span Length: 1318
# Excluding example due to context length > 400. Question: did kenny smith play with michael jordan at north carolina
# File simplified_natural_questions/nq-train-14_simplified.jsonl.gz processed.
#   Oversized long answers handled: 11
#   Excluded examples: 17
# Processing file: simplified_natural_questions/nq-train-02_simplified.jsonl.gz
# Excluding example. Question: is the us a part of the un, Span Length: 4835
# Excluding example due to context length > 400. Question: does penny die in out of my mind
# Excluding example due to context length > 400. Question: is jason alexander on comedians in cars getting coffee
# Excluding example due to context length > 400. Question: does canada's worst driver lose their license
# Excluding example. Question: do you need a visa for colombia from australia, Span Length: 3861
# File simplified_natural_questions/nq-train-02_simplified.jsonl.gz processed.
#   Oversized long answers handled: 2
#   Excluded examples: 5
# Processing file: simplified_natural_questions/nq-train-41_simplified.jsonl.gz
# Excluding example. Question: chrome shelled regios does layfon get his heaven's blade back, Span Length: 6479
# Excluding example due to context length > 400. Question: is it illegal to sell sperm in the uk
# Excluding example. Question: do hong kong citizens need a visa for canada, Span Length: 4130
# Excluding example. Question: is it illegal to grow mushrooms in canada, Span Length: 2801
# Excluding example due to context length > 400. Question: are there any presidential libraries in new york
# Excluding example. Question: does a nigerian need visa to travel to south africa, Span Length: 2403
# Excluding example due to context length > 400. Question: have the mets and yankees ever played in a world series
# File simplified_natural_questions/nq-train-41_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 7
# Processing file: simplified_natural_questions/nq-train-48_simplified.jsonl.gz
# Excluding example. Question: does sarah have her baby in a place to call home, Span Length: 3445
# Excluding example. Question: has there been a school shooting in kansas, Span Length: 3338
# Excluding example due to context length > 400. Question: has purdue ever made it to the final four
# Excluding example due to context length > 400. Question: has beyonce won album of the year grammy
# Excluding example due to context length > 400. Question: is ron howard a producer of this is us
# Excluding example due to context length > 400. Question: is victoria day a stat holiday in quebec
# Excluding example. Question: does quinn die in one tree hill season 8, Span Length: 3087
# Excluding example. Question: do south african passport holders need a visa for romania, Span Length: 3890
# File simplified_natural_questions/nq-train-48_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-26_simplified.jsonl.gz
# Excluding example. Question: was the cuban missile crisis a proxy war, Span Length: 5449
# Excluding example. Question: are there hurricanes in the bahamas in october, Span Length: 2245
# Excluding example due to context length > 400. Question: can you carry a gun in your car without a license in texas
# Excluding example. Question: did steve carell and will ferrell write a movie together, Span Length: 1481
# Excluding example due to context length > 400. Question: has there ever been a cat 5 hurricane hit the us
# Excluding example. Question: do i need a cuban passport to go to cuba, Span Length: 3376
# Excluding example due to context length > 400. Question: do you need a gun license in texas
# Excluding example due to context length > 400. Question: do i need to register a gun in nevada
# File simplified_natural_questions/nq-train-26_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-42_simplified.jsonl.gz
# Excluding example. Question: does a thai need a visa for singapore, Span Length: 3019
# Excluding example. Question: does each us state have its own constitution, Span Length: 1083
# Excluding example. Question: does a south african passport holder need a visa for japan, Span Length: 4796
# Excluding example. Question: is san francisco the largest city in california, Span Length: 7217
# File simplified_natural_questions/nq-train-42_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 4
# Processing file: simplified_natural_questions/nq-train-31_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: is it legal to own a skunk in illinois
# Excluding example due to context length > 400. Question: does the queen have a castle in scotland
# Excluding example. Question: do indian passport holders need a visa for sri lanka, Span Length: 4661
# Excluding example due to context length > 400. Question: can you buy a gun in indiana without a permit
# Excluding example. Question: do australian passport holders need a visa to visit canada, Span Length: 3886
# Excluding example. Question: is there an international airport in new jersey, Span Length: 1539
# Excluding example due to context length > 400. Question: do you have to identify yourself to a police officer in illinois
# Excluding example due to context length > 400. Question: did michael jordan win a championship with the wizards
# File simplified_natural_questions/nq-train-31_simplified.jsonl.gz processed.
#   Oversized long answers handled: 3
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-15_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: when was the last time america won the world cup
# Excluding example due to context length > 400. Question: can i open carry a handgun in texas
# Excluding example. Question: do usa citizens need a visa for peru, Span Length: 3944
# Excluding example. Question: do luke and lorelai get married in season 7, Span Length: 3205
# Excluding example. Question: does bill die in true blood season 1, Span Length: 6371
# Excluding example due to context length > 400. Question: is there any holiday on 12 september 2017
# Excluding example due to context length > 400. Question: is puerto rico a state of the united states of america
# Excluding example due to context length > 400. Question: is there a pool at canobie lake park
# Excluding example. Question: do you need a visa for dubai from new zealand, Span Length: 3560
# File simplified_natural_questions/nq-train-15_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-04_simplified.jsonl.gz
# Excluding example. Question: did rick and morty season 3 episode 6 air, Span Length: 2753
# Excluding example. Question: is green arrow a member of the justice league, Span Length: 2248
# Excluding example due to context length > 400. Question: can you open carry a pistol in arkansas
# Excluding example. Question: is there a world trade center in every state, Span Length: 7173
# Excluding example due to context length > 400. Question: are guns banned in the district of columbia
# Excluding example due to context length > 400. Question: do i have to give my name to police nj
# Excluding example. Question: do i need a visa for slovakia from australia, Span Length: 4322
# Excluding example. Question: do i need a visa for dubai from nz, Span Length: 4411
# Excluding example. Question: can you get a tattoo at 15 in sc, Span Length: 4889
# Excluding example due to context length > 400. Question: were the ten commandments in the old testament
# Excluding example due to context length > 400. Question: has there ever been an earthquake in illinois
# File simplified_natural_questions/nq-train-04_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-10_simplified.jsonl.gz
# Excluding example. Question: is there a minimum wage in the dominican republic, Span Length: 15111
# Excluding example due to context length > 400. Question: will apple watch 1 work with iphone 7
# Excluding example. Question: has florida ever had a category 5 hurricane, Span Length: 2245
# File simplified_natural_questions/nq-train-10_simplified.jsonl.gz processed.
#   Oversized long answers handled: 2
#   Excluded examples: 3
# Processing file: simplified_natural_questions/nq-train-27_simplified.jsonl.gz
# Excluding example. Question: does a south african citizen need a visa to visit thailand, Span Length: 4567
# Excluding example. Question: do you need a visa to travel to norway from australia, Span Length: 3716
# Excluding example. Question: can you get a tattoo in california with parental consent, Span Length: 4892
# Excluding example. Question: does a bulgarian citizen need a visa to enter u.s, Span Length: 3362
# Excluding example due to context length > 400. Question: does snow white have a star on the hollywood walk of fame
# File simplified_natural_questions/nq-train-27_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 5
# Processing file: simplified_natural_questions/nq-train-08_simplified.jsonl.gz
# Excluding example. Question: did tyler die in vampire diaries season 6, Span Length: 7458
# Excluding example due to context length > 400. Question: does the 4 train stop at 59th street
# Excluding example. Question: do brazilian citizens need a visa for italy, Span Length: 3586
# Excluding example. Question: was there a new episode of chicago fire last night, Span Length: 1037
# Excluding example. Question: do you need a visa from ghana to jamaica, Span Length: 2915
# Excluding example. Question: can you get a tattoo with parental consent in oregon, Span Length: 4894
# Excluding example. Question: is a toyota corolla considered a midsize car, Span Length: 1156
# Excluding example due to context length > 400. Question: did maradona won fifa player of the year
# Excluding example. Question: is cyprus a member of the british commonwealth, Span Length: 2302
# File simplified_natural_questions/nq-train-08_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-45_simplified.jsonl.gz
# Excluding example. Question: is saint pierre and miquelon part of the eu, Span Length: 2566
# Excluding example due to context length > 400. Question: is there going to be a new star wars movie after the last jedi
# Excluding example due to context length > 400. Question: can you open carry a rifle in iowa
# Excluding example. Question: is it legal to get a tattoo at 17 in texas, Span Length: 4889
# Excluding example. Question: is mall of america the biggest mall in north america, Span Length: 2742
# Excluding example. Question: does shadow the hedgehog work on xbox 360, Span Length: 20526
# Excluding example due to context length > 400. Question: do you have to show id to police in mn
# Excluding example. Question: do mexican citizens need a visa for uk, Span Length: 3471
# Excluding example due to context length > 400. Question: is sesame street the longest running tv show
# Excluding example due to context length > 400. Question: flesh and bone is there a season 2
# Excluding example due to context length > 400. Question: is one direction the biggest boyband in history
# File simplified_natural_questions/nq-train-45_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-46_simplified.jsonl.gz
# Excluding example. Question: has anyone won the stanley cup three years in a row, Span Length: 2592
# Excluding example. Question: can a minor get a tattoo in tennessee, Span Length: 4889
# Excluding example. Question: does an american need a visa to go to south korea, Span Length: 7363
# Excluding example. Question: do german citizens need a visa for india, Span Length: 3684
# Excluding example. Question: does a british citizen require a visa for usa, Span Length: 4538
# Excluding example due to context length > 400. Question: are drake and elena married in uncharted 3
# Excluding example. Question: have england ever won a world cup penalty shoot out, Span Length: 2080
# Excluding example. Question: do jamaicans need a visa to travel to colombia, Span Length: 3344
# File simplified_natural_questions/nq-train-46_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-38_simplified.jsonl.gz
# Excluding example. Question: is simpsons hit and run compatible with ps3, Span Length: 4684
# Excluding example. Question: does a filipino need a visa to enter malaysia, Span Length: 3558
# Excluding example. Question: do you need a visa from singapore to malaysia, Span Length: 3508
# Excluding example. Question: can you buy alcohol on new year's day in georgia, Span Length: 2333
# Excluding example due to context length > 400. Question: does anyone find out that dan killed keith
# Excluding example. Question: does costa rica have an extradition treaty with the us, Span Length: 3928
# Excluding example. Question: do new zealand citizens need a visa for spain, Span Length: 4463
# Excluding example due to context length > 400. Question: is there bank of america in other countries
# Excluding example. Question: do jane and michael get together in season 2, Span Length: 4072
# Excluding example. Question: love child does annie get her baby back, Span Length: 1046
# Excluding example. Question: can you play black ops on xbox one s, Span Length: 15476
# Excluding example. Question: do australian passport holders need a visa for laos, Span Length: 4335
# File simplified_natural_questions/nq-train-38_simplified.jsonl.gz processed.
#   Oversized long answers handled: 10
#   Excluded examples: 12
# Processing file: simplified_natural_questions/nq-train-18_simplified.jsonl.gz
# Excluding example. Question: do moroccans need a visa to go to mexico, Span Length: 3851
# Excluding example. Question: is it legal to marry your sister in alabama, Span Length: 4420
# Excluding example due to context length > 400. Question: has the us men's soccer team won a world cup
# Excluding example due to context length > 400. Question: do you have to identify yourself in new jersey
# Excluding example due to context length > 400. Question: is american airlines a member of star alliance
# Excluding example. Question: has there ever been a school shooting in ny, Span Length: 1473
# Excluding example due to context length > 400. Question: true or false the 2004 sumatra tsunami caused deaths in the pacific northwest
# Excluding example due to context length > 400. Question: do i need to register my gun in tennessee
# Excluding example. Question: were arthur and molly weasley in the original order of the phoenix, Span Length: 1583
# Excluding example. Question: does a canadian need a visa for germany, Span Length: 4774
# Excluding example due to context length > 400. Question: do you need a permit to open carry in virginia
# File simplified_natural_questions/nq-train-18_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 11
# Processing file: simplified_natural_questions/nq-train-36_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: where do jamie and claire live in america
# Excluding example. Question: do canadian citizens need a visa to visit russia, Span Length: 4565
# Excluding example. Question: can you buy alcohol in ct on thanksgiving, Span Length: 2333
# Excluding example. Question: is new york city the biggest city in the world, Span Length: 4396
# Excluding example. Question: does hong kong have more skyscrapers than new york, Span Length: 2743
# Excluding example due to context length > 400. Question: do you need a permit to open carry in va
# Excluding example due to context length > 400. Question: can you conceal carry in utah without a permit
# Excluding example. Question: does ty come back in season 2 of heartland, Span Length: 7723
# Excluding example due to context length > 400. Question: is there a season 5 of senora acero
# File simplified_natural_questions/nq-train-36_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-40_simplified.jsonl.gz
# Excluding example. Question: new zealand extradition treaty with the united states, Span Length: 3928
# Excluding example due to context length > 400. Question: does a south african need a visa for macau
# Excluding example. Question: is crossiron mills bigger than west edmonton mall, Span Length: 4162
# Excluding example. Question: can you buy beer 24 hours in texas, Span Length: 1594
# Excluding example. Question: the good wife does alicia leave the firm, Span Length: 4214
# Excluding example. Question: do indian passport holders need visa for armenia, Span Length: 4841
# File simplified_natural_questions/nq-train-40_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 6
# Processing file: simplified_natural_questions/nq-train-37_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: can you carry a gun in tn without permit
# Excluding example due to context length > 400. Question: is blue of blue's clues a girl
# Excluding example. Question: do vehicles need to be inspected in north carolina, Span Length: 1088
# Excluding example due to context length > 400. Question: do i have to show police id in florida
# Excluding example. Question: does british citizen need visa for south africa, Span Length: 4546
# Excluding example due to context length > 400. Question: is chile going to the world cup 2018
# Excluding example due to context length > 400. Question: is easter monday a public holiday in france
# Excluding example due to context length > 400. Question: was edna from the incredibles based on linda hunt
# Excluding example. Question: have the patriots won two superbowls in a row, Span Length: 5020
# Excluding example. Question: do uk citizens need a visa for georgia, Span Length: 4206
# Excluding example due to context length > 400. Question: do the las vegas knights have a captain
# Excluding example. Question: do nz passport holders need a visa for france, Span Length: 4465
# Excluding example due to context length > 400. Question: is there still a six flags in ohio
# File simplified_natural_questions/nq-train-37_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 13
# Processing file: simplified_natural_questions/nq-train-07_simplified.jsonl.gz
# Excluding example. Question: is it illegal to talk on your cell phone while driving in pennsylvania, Span Length: 1841
# Excluding example due to context length > 400. Question: has the us ever won the mens world cup
# Excluding example. Question: who was appointed to the high court of australia brewery, Span Length: 2653
# Excluding example due to context length > 400. Question: is the state of virginia an open carry state
# Excluding example. Question: is vaughan mills the largest mall in canada, Span Length: 4213
# Excluding example. Question: does the czech republic have universal health care, Span Length: 2288
# Excluding example. Question: can you play gta vice city on xbox 360, Span Length: 12071
# Excluding example. Question: is england the only country with a royal family, Span Length: 2036
# Excluding example. Question: can you play xbox classic games on xbox 360, Span Length: 20282
# Excluding example. Question: is india the third largest country in the world, Span Length: 11239
# Excluding example. Question: can you legally marry your first cousin in the us, Span Length: 1875
# Excluding example. Question: is i 65 in indiana a toll road, Span Length: 2625
# File simplified_natural_questions/nq-train-07_simplified.jsonl.gz processed.
#   Oversized long answers handled: 10
#   Excluded examples: 12
# Processing file: simplified_natural_questions/nq-train-30_simplified.jsonl.gz
# Excluding example. Question: is it legal to talk on the phone while driving in indiana, Span Length: 1841
# Excluding example due to context length > 400. Question: is it illegal to have a pet skunk in california
# Excluding example due to context length > 400. Question: did the mayans and aztecs speak the same language
# Excluding example. Question: can you marry your first cousin in indiana, Span Length: 1875
# Excluding example. Question: can you get a tattoo at 16 in wa, Span Length: 4893
# Excluding example. Question: is greece a member of the european union, Span Length: 2080
# Excluding example. Question: is hungary a member of the european union, Span Length: 2122
# Excluding example. Question: can a minor get a tattoo in california, Span Length: 4892
# Excluding example. Question: do italian citizens need a visa to enter brazil, Span Length: 4493
# File simplified_natural_questions/nq-train-30_simplified.jsonl.gz processed.
#   Oversized long answers handled: 7
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-47_simplified.jsonl.gz
# Excluding example due to context length > 400. Question: do you have to register rifles in maryland
# Excluding example due to context length > 400. Question: do i need a transit visa for hong kong
# Excluding example. Question: is it illegal to smoke tobacco under 18 in pa, Span Length: 5431
# Excluding example. Question: do new zealand passport holders need a visa for portugal, Span Length: 4411
# Excluding example. Question: is a uk king the same as a us queen, Span Length: 1153
# Excluding example due to context length > 400. Question: is turkish airlines a member of the star alliance
# Excluding example. Question: does a zimbabwean need a visa for kenya, Span Length: 2975
# Excluding example. Question: would xbox one games work on xbox 360, Span Length: 13070
# Excluding example. Question: is florida state university a division 1 school, Span Length: 9498
# File simplified_natural_questions/nq-train-47_simplified.jsonl.gz processed.
#   Oversized long answers handled: 6
#   Excluded examples: 9
# Processing file: simplified_natural_questions/nq-train-49_simplified.jsonl.gz
# Excluding example. Question: do new zealand citizens need visa for us, Span Length: 4539
# Excluding example due to context length > 400. Question: can you have a pet skunk in washington
# Excluding example due to context length > 400. Question: one tree hill episode brooke finds out she's pregnant
# Excluding example. Question: who wants to be a millionaire has anyone ever won, Span Length: 8458
# Excluding example. Question: do you need a visa for singapore from canada, Span Length: 4599
# Excluding example. Question: do jordanians need a visa to sri lanka, Span Length: 6431
# Excluding example. Question: do uk citizens require a visa for australia, Span Length: 4310
# Excluding example due to context length > 400. Question: is austrian airlines part of the star alliance
# File simplified_natural_questions/nq-train-49_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 8
# Processing file: simplified_natural_questions/nq-train-03_simplified.jsonl.gz
# Excluding example. Question: is it a bank holiday today in spain, Span Length: 2133
# Excluding example. Question: can i travel to bahamas with a jamaican passport, Span Length: 3344
# Excluding example due to context length > 400. Question: was dwight the father of angela's baby
# Excluding example. Question: is there a new dragon ball super episode, Span Length: 18629
# Excluding example. Question: is stephen curry the greatest 3 point shooter of all time, Span Length: 2929
# File simplified_natural_questions/nq-train-03_simplified.jsonl.gz processed.
#   Oversized long answers handled: 4
#   Excluded examples: 5
# Processing file: simplified_natural_questions/nq-train-17_simplified.jsonl.gz
# Excluding example. Question: india is the second largest english speaking country, Span Length: 5610
# Excluding example due to context length > 400. Question: does mellow yellow have grapefruit juice in it
# Excluding example. Question: has aerosmith been inducted into the rock and roll hall of fame, Span Length: 6414
# Excluding example. Question: does japan have an extradition treaty with the us, Span Length: 3928
# Excluding example. Question: is there a city in turkey called santa claus, Span Length: 15137
# Excluding example due to context length > 400. Question: is unc wilmington part of unc chapel hill
# Excluding example due to context length > 400. Question: does a 2013 honda civic lx have vtec
# Excluding example. Question: does singapore passport need visa to new zealand, Span Length: 5274
# File simplified_natural_questions/nq-train-17_simplified.jsonl.gz processed.
#   Oversized long answers handled: 5
#   Excluded examples: 8
# Processing complete. Balanced yes/no data saved to balanced_yes_no_data.json
# Counts of each question type in the dataset:
# Counter({'YES': 1235, 'NO': 1235})

# %% [markdown]
# Here is the code section for processing Short Answer questions: This part processes span-based questions where a brief, specific answer is extracted from the context.

# %%
# Extract Context Window
def extract_context(document, start_token, end_token, window_size=50):
    tokens = document.split(" ")
    doc_length = len(tokens)

    if doc_length == 0:
        raise ValueError("Document is empty.")

    # Define window boundaries with some randomness
    max_pre_shift = max(0, start_token - 1)
    max_post_shift = max(0, doc_length - end_token - 1)
    random_shift = random.randint(-min(max_pre_shift, window_size), min(max_post_shift, window_size))

    pre_start = max(0, start_token - window_size + random_shift)
    post_end = min(doc_length, end_token + window_size + random_shift)

    # Create the randomized context window
    context_window = " ".join(tokens[pre_start:post_end])

    if not context_window.strip():
        raise ValueError("Extracted context window is empty.")

    # Adjust start and end tokens
    adjusted_start = start_token - pre_start
    adjusted_end = end_token - pre_start

    return context_window, adjusted_start, adjusted_end

print("extract_context function defined.")
# Out:
# clean_html function defined.
# extract_context function defined.

# %%
# Clean HTML and Adjust Spans
def clean_html_and_adjust_spans(context, start_token, end_token):
    soup = BeautifulSoup(context, "html.parser")
    plain_text = soup.get_text(separator=" ")

    # Split tokens before and after cleaning
    original_tokens = context.split(" ")
    cleaned_tokens = plain_text.split(" ")

    if start_token >= len(original_tokens) or end_token > len(original_tokens):
        raise ValueError("Start or end token indices are out of bounds.")

    # Map original tokens to cleaned tokens
    token_map = {}
    clean_index = 0
    for i, token in enumerate(original_tokens):
        if clean_index < len(cleaned_tokens) and token == cleaned_tokens[clean_index]:
            token_map[i] = clean_index
            clean_index += 1

    adjusted_start = token_map.get(start_token, -1)
    adjusted_end = token_map.get(end_token - 1, -1) + 1  # +1 for exclusive range

    if adjusted_start == -1 or adjusted_end == -1:
        print(f"Failed to map tokens for Context: {context}")
        raise ValueError("Failed to map token indices after HTML cleaning.")

    return plain_text, adjusted_start, adjusted_end

print("clean_html_and_adjust_spans function defined.")

# %%
# Process Short Answers
def process_short_answers(file_path, output_data, max_short_answers=2000, window_size=50):
    try:
        with gzip.open(file_path, 'rt', encoding='utf-8') as file:
            for line in file:
                if len(output_data) >= max_short_answers:
                    break

                example = json.loads(line)
                question = example.get('question_text', "")
                document = example.get('document_text', "")
                annotations = example.get('annotations', [])

                if not document.strip():
                    print("Skipping example due to empty document.")
                    continue

                for annotation in annotations:
                    short_answers = annotation.get('short_answers', [])
                    for sa in short_answers:
                        start_token = sa.get('start_token')
                        end_token = sa.get('end_token')

                        if start_token is None or end_token is None or start_token >= len(document.split(" ")):
                            print(f"Skipping invalid span: Start: {start_token}, End: {end_token}")
                            continue

                        try:
                            context_window, adjusted_start, adjusted_end = extract_context(
                                document, start_token, end_token, window_size
                            )
                            cleaned_context, cleaned_start, cleaned_end = clean_html_and_adjust_spans(
                                context_window, adjusted_start, adjusted_end
                            )

                            output_data.append({
                                "type": "short_answer",
                                "question": question,
                                "document": cleaned_context,
                                "start_token": cleaned_start,
                                "end_token": cleaned_end
                            })
                        except ValueError as e:
                            print(f"Skipping example due to error: {e}")
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

print("process_short_answers function defined.")

# %%
# Here we run the process_short_answers

input_folder = "Newsimplified_natural_questions"
short_answer_data = []

all_files = [file for file in os.listdir(input_folder) if file.endswith(".jsonl.gz")]

num_files_to_process = 50
files_to_process = all_files[:num_files_to_process]

for file_name in files_to_process:
    if len(short_answer_data) >= 2000:
        break
    file_path = os.path.join(input_folder, file_name)
    process_short_answers(file_path, short_answer_data, max_short_answers=2000)

# Save processed data
output_file = "short_answers_data.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(short_answer_data, f, indent=4)

print(f"Processing complete. Short answers with context saved to {output_file}.")

# %% [markdown]
# Here is the code section for processing Long Answer questions: This section deals with span-based tasks requiring the extraction of extended context as the answer.

# %%
# Count HTML Tags
def count_html_tags(context_window):
    soup = BeautifulSoup(context_window, "html.parser")
    return len(soup.find_all())

print("count_html_tags function defined.")

# Extract Context with Randomization
def extract_context_with_randomization(document, start_token, end_token, window_size=100):
    tokens = document.split(" ")
    doc_length = len(tokens)

    # Define the boundaries with random shifts
    max_pre_shift = max(0, start_token - 1)
    max_post_shift = max(0, doc_length - end_token - 1)
    random_shift = random.randint(-min(max_pre_shift, window_size), min(max_post_shift, window_size))

    pre_start = max(0, start_token - window_size + random_shift)
    post_end = min(doc_length, end_token + window_size + random_shift)

    # Create the context window
    context_window = " ".join(tokens[pre_start:post_end])

    # Adjust start and end tokens relative to the new context window
    adjusted_start = start_token - pre_start
    adjusted_end = end_token - pre_start

    return context_window, adjusted_start, adjusted_end

print("extract_context_with_randomization function defined.")

# %%
# Process Long Answers
def process_long_answers(file_path, output_data, max_long_answers=2000, window_size=100, max_html_tags=5):
    try:
        with gzip.open(file_path, 'rt', encoding='utf-8') as file:
            for line in file:
                if len(output_data) >= max_long_answers:
                    break

                # Parse JSON line
                example = json.loads(line)
                question = example.get('question_text', "")
                document = example.get('document_text', "")
                annotations = example.get('annotations', [])

                # Process each annotation
                for annotation in annotations:
                    long_answer = annotation.get('long_answer', {})
                    start_token = long_answer.get('start_token')
                    end_token = long_answer.get('end_token')

                    # Skip if tokens are invalid or exceed the threshold
                    if (
                        start_token is None or end_token is None or
                        start_token == -1 or end_token == -1 or
                        (end_token - start_token) >= 100
                    ):
                        continue

                    # Extract the randomized context window
                    try:
                        context_window, adjusted_start, adjusted_end = extract_context_with_randomization(
                            document, start_token, end_token, window_size
                        )
                    except ValueError as e:
                        print(f"Skipping example due to context extraction error: {e}")
                        continue

                    # Skip examples with too many HTML tags
                    if count_html_tags(context_window) > max_html_tags:
                        continue

                    # Append processed example
                    output_data.append({
                        "type": "long_answer",
                        "question": question,
                        "document": context_window,
                        "start_token": adjusted_start,
                        "end_token": adjusted_end,
                    })
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

print("process_long_answers function defined.")

# %%
# Here we run the process_long_answers

input_folder = "Newsimplified_natural_questions"
long_answer_data = []

all_files = [file for file in os.listdir(input_folder) if file.endswith(".jsonl.gz")]

num_files_to_process = 50 
files_to_process = all_files[:num_files_to_process]

for file_name in files_to_process:
    if len(long_answer_data) >= 2000:
        break
    file_path = os.path.join(input_folder, file_name)
    process_long_answers(file_path, long_answer_data, max_long_answers=2000)

output_file = "long_answers_data.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(long_answer_data, f, indent=4)

print(f"Processing complete. Extracted long answers saved to {output_file}.")

# %% [markdown]
# After running the chosen QA task, we can proceed with the following training, validation, and testing steps.

# %%
# Define File Paths and Task Type
tokenized_data_path = "balanced_yes_no_data.json" # Options: "balanced_yes_no_data.json", "short_answers_data.json", "long_answers_data.json"
train_path = "train_data.json"
val_path = "val_data.json"
test_path = "test_data.json"

# Task type
task_type = "yes_no"  # Options: "yes_no", "short_answer", "long_answer"
print(f"Task type: {task_type}")
# Out:
# Task type: yes_no

# %%
# Split Dataset Function
def split_dataset(tokenized_data_path, train_path, val_path, test_path, task_type=None, test_size=0.3, random_state=42):
    with open(tokenized_data_path, "r", encoding="utf-8") as f:
        tokenized_data = json.load(f)

    # Filter by task_type
    if task_type:
        tokenized_data = [item for item in tokenized_data if item["type"] == task_type]

    # Split into train, validation, and test sets
    train_data, temp_data = train_test_split(tokenized_data, test_size=test_size, random_state=random_state)
    val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=random_state)

    # Save splits
    with open(train_path, "w", encoding="utf-8") as f:
        json.dump(train_data, f, indent=4)
    with open(val_path, "w", encoding="utf-8") as f:
        json.dump(val_data, f, indent=4)
    with open(test_path, "w", encoding="utf-8") as f:
        json.dump(test_data, f, indent=4)

    print("Dataset split into train, validation, and test sets.")

print("Splitting the dataset...")
split_dataset(tokenized_data_path, train_path, val_path, test_path, task_type=task_type)
# Out:
# Splitting the dataset...
# Dataset split into train, validation, and test sets.

# %%
# Define collate_fn Function for DataLoader

def collate_fn(batch):
    input_ids = [item["input_ids"] for item in batch]
    attention_mask = [item["attention_mask"] for item in batch]
    types = [item["type"] for item in batch]

    # Initialize empty lists for optional fields
    labels = []
    start_positions = []
    end_positions = []

    for item in batch:
        if item["type"] == "yes_no":
            labels.append(item["label"])
        elif item["type"] in ["long_answer", "short_answer"]:
            start_positions.append(item["start_positions"])
            end_positions.append(item["end_positions"])

    collated_data = {
        "input_ids": pad_sequence(input_ids, batch_first=True, padding_value=0),
        "attention_mask": pad_sequence(attention_mask, batch_first=True, padding_value=0),
        "types": types,
    }

    if labels:
        collated_data["labels"] = torch.tensor(labels, dtype=torch.long)
    if start_positions and end_positions:
        collated_data["start_positions"] = torch.tensor(start_positions, dtype=torch.long)
        collated_data["end_positions"] = torch.tensor(end_positions, dtype=torch.long)

    return collated_data

print("collate_fn function defined.")
# Out:
# collate_fn function defined.

# %%
# Define QADataset Class
class QADataset(Dataset):
    def __init__(self, file_path, task_type="long_answer", tokenizer_name="bert-base-uncased"):
        with open(file_path, "r", encoding="utf-8") as f:
            self.data = [item for item in json.load(f) if item["type"] == task_type]
        self.task_type = task_type
        self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        # Tokenize with offset mapping
        tokenized = self.tokenizer(
            item["question"],
            item["document"],
            truncation=True,
            max_length=512,
            padding="max_length",
            return_tensors="pt",
            return_offsets_mapping=(self.task_type in ["short_answer", "long_answer"])
        )

        input_ids = tokenized["input_ids"].squeeze(0).tolist()
        attention_mask = tokenized["attention_mask"].squeeze(0).tolist()

        # Prepare output based on task type
        output = {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "attention_mask": torch.tensor(attention_mask, dtype=torch.long),
            "type": item["type"],
        }

        if self.task_type == "yes_no":
            output["label"] = torch.tensor(1 if item.get("yes_no_answer") == "YES" else 0, dtype=torch.long)
        elif self.task_type in ["short_answer", "long_answer"]:
            offset_mapping = tokenized["offset_mapping"].squeeze(0).tolist()
            sep_index = input_ids.index(self.tokenizer.sep_token_id) + 1

            # Adjust start and end positions using offset mapping (only for span-based tasks)
            tokenized_start, tokenized_end = None, None
            char_start = len(" ".join(item["document"].split()[:item["start_token"]])) + 1
            char_end = len(" ".join(item["document"].split()[:item["end_token"]]))

            for idx, (start_offset, end_offset) in enumerate(offset_mapping[sep_index:], start=sep_index):
                if start_offset <= char_start < end_offset:
                    tokenized_start = idx
                if start_offset < char_end <= end_offset:
                    tokenized_end = idx

            if tokenized_start is None or tokenized_end is None:
                # Attempt to map span using a more relaxed approach
                for idx, (start_offset, end_offset) in enumerate(offset_mapping):
                    if start_offset <= char_start <= end_offset:
                        tokenized_start = idx
                    if start_offset <= char_end <= end_offset:
                        tokenized_end = idx

                if tokenized_start is None or tokenized_end is None:
                    print(f"Failed to map tokens for example {idx}.")
                    print(f"Question: {item['question']}")
                    print(f"Document: {item['document']}")
                    print(f"Start Token: {item['start_token']}, End Token: {item['end_token']}")
                    print(f"Character Start: {char_start}, Character End: {char_end}")
                    print(f"Offset Mapping: {offset_mapping}")
                    raise ValueError(f"Failed to map tokens for example {idx}.")

            output["start_positions"] = torch.tensor(tokenized_start, dtype=torch.long)
            output["end_positions"] = torch.tensor(tokenized_end, dtype=torch.long)

        return output

print("QADataset class defined.")
# Out:
# QADataset class defined.

# %%
# Here is the important paramters:
batch_size = 8
learning_rate = 4e-5
num_epochs = 5

# %%
# Data Loaders
print("Creating data loaders...")
train_dataset = QADataset(train_path, task_type=task_type)
val_dataset = QADataset(val_path, task_type=task_type)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=collate_fn)

# Model and Optimizer
print("Initializing model and optimizer...")

if task_type == "yes_no":
    model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
elif task_type in ["short_answer", "long_answer"]:
    model = BertForQuestionAnswering.from_pretrained("bert-base-uncased")
    print("Loaded BertForQuestionAnswering for span-based tasks.")
else:
    raise ValueError(f"Unknown task type: {task_type}")

model.to(device)
optimizer = AdamW(model.parameters(), lr=learning_rate)
# Out:
# Creating data loaders...
# Initializing model and optimizer...
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/alin/.local/lib/python3.10/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Training Loop
print("Starting training...")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    yes_correct = 0
    no_correct = 0
    yes_total = 0
    no_total = 0

    for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{num_epochs}"):
        optimizer.zero_grad()
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        if task_type == "yes_no":
            labels = batch["labels"].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss

            # Predictions for accuracy
            predictions = torch.argmax(outputs.logits, dim=1)
            yes_correct += ((predictions == 1) & (labels == 1)).sum().item()
            no_correct += ((predictions == 0) & (labels == 0)).sum().item()
            yes_total += (labels == 1).sum().item()
            no_total += (labels == 0).sum().item()

        elif task_type in ["short_answer", "long_answer"]:
            start_positions = batch["start_positions"].to(device)
            end_positions = batch["end_positions"].to(device)
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                start_positions=start_positions,
                end_positions=end_positions,
            )
            loss = outputs.loss

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch + 1} - Loss: {total_loss / len(train_loader)}")

    if task_type == "yes_no":
        yes_accuracy = yes_correct / yes_total if yes_total > 0 else 0
        no_accuracy = no_correct / no_total if no_total > 0 else 0
        print(f"Training YES Accuracy: {yes_accuracy:.4f}")
        print(f"Training NO Accuracy: {no_accuracy:.4f}")
# Out:
# Starting training...
# Training Epoch 1/5: 100%|██████████| 217/217 [00:26<00:00,  8.27it/s]
# Epoch 1 - Loss: 0.6984546407027179
# Training YES Accuracy: 0.4954
# Training NO Accuracy: 0.4786
# Training Epoch 2/5: 100%|██████████| 217/217 [00:26<00:00,  8.24it/s]
# Epoch 2 - Loss: 0.6833275133563627
# Training YES Accuracy: 0.5358
# Training NO Accuracy: 0.5898
# Training Epoch 3/5: 100%|██████████| 217/217 [00:26<00:00,  8.25it/s]
# Epoch 3 - Loss: 0.5812813378698815
# Training YES Accuracy: 0.6859
# Training NO Accuracy: 0.7161
# Training Epoch 4/5: 100%|██████████| 217/217 [00:26<00:00,  8.22it/s]
# Epoch 4 - Loss: 0.27626121874194814
# Training YES Accuracy: 0.8961
# Training NO Accuracy: 0.8992
# Training Epoch 5/5: 100%|██████████| 217/217 [00:26<00:00,  8.19it/s]
# Epoch 5 - Loss: 0.09752215037963563
# Training YES Accuracy: 0.9654
# Training NO Accuracy: 0.9664

# %%
# Validation Loop
print("Starting validation...")

model.eval()
span_metrics = {"exact_match": 0, "f1": 0}
total_span_examples = 0
all_labels, all_predictions = [], []

with torch.no_grad():
    for batch in tqdm(val_loader, desc="Evaluating"):
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        if task_type == "yes_no":
            labels = batch["labels"].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            predictions = torch.argmax(outputs.logits, dim=1)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predictions.cpu().numpy())

        elif task_type in ["short_answer", "long_answer"]:
            start_positions = batch["start_positions"].to(device)
            end_positions = batch["end_positions"].to(device)
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                start_positions=start_positions,
                end_positions=end_positions
            )
            start_preds = torch.argmax(outputs.start_logits, dim=1)
            end_preds = torch.argmax(outputs.end_logits, dim=1)

            for i in range(len(start_positions)):
                pred_span = set(range(start_preds[i].item(), end_preds[i].item() + 1))
                true_span = set(range(start_positions[i].item(), end_positions[i].item() + 1))
                if pred_span == true_span:
                    span_metrics["exact_match"] += 1
                intersection = len(pred_span & true_span)
                precision = intersection / len(pred_span) if pred_span else 0
                recall = intersection / len(true_span) if true_span else 0
                f1 = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
                span_metrics["f1"] += f1

            total_span_examples += len(start_positions)

if task_type == "yes_no":
    yes_accuracy = accuracy_score(all_labels, all_predictions)
    report = classification_report(all_labels, all_predictions, target_names=["NO", "YES"])
    print(f"Validation Accuracy: {yes_accuracy:.4f}")
    print(report)

if total_span_examples > 0:
    span_metrics["exact_match"] /= total_span_examples
    span_metrics["f1"] /= total_span_examples
    print(f"Validation Exact Match (EM): {span_metrics['exact_match']:.4f}")
    print(f"Validation F1 Score: {span_metrics['f1']:.4f}")
# Out:
# Starting validation...
# Evaluating: 100%|██████████| 47/47 [00:01<00:00, 23.78it/s]
# Validation Accuracy: 0.5676
#               precision    recall  f1-score   support
#
#           NO       0.57      0.37      0.44       175
#          YES       0.57      0.75      0.65       195
#
#     accuracy                           0.57       370
#    macro avg       0.57      0.56      0.55       370
# weighted avg       0.57      0.57      0.55       370

# %%
# Load Fine-Tuned Model and Tokenizer
model_path = f"./fine_tuned_bert_{task_type}_model"
tokenizer_path = model_path

if task_type == "yes_no":
    model = DistilBertForSequenceClassification.from_pretrained(model_path)
elif task_type in ["short_answer", "long_answer"]:
    model = BertForQuestionAnswering.from_pretrained(model_path)
else:
    raise ValueError(f"Unsupported task type: {task_type}")

tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model.to(device)
model.eval()

print(f"Loaded model and tokenizer for task type: {task_type}")
# Out:
# Loaded model and tokenizer for task type: yes_no

# %%
# Save Model and Tokenizer
output_dir = f"./fine_tuned_bert_{task_type}_model"
os.makedirs(output_dir, exist_ok=True)
model.save_pretrained(output_dir)
train_dataset.tokenizer.save_pretrained(output_dir)
print(f"Model saved to {output_dir}.")
# Out:
# Model saved to ./fine_tuned_bert_yes_no_model.

# %% [markdown]
# Here is tests

# %%
# Load Test Data
test_path = "test_data.json"
with open(test_path, "r", encoding="utf-8") as f:
    test_data = json.load(f)

print(f"Loaded test data from {test_path}. Total examples: {len(test_data)}")

# Define Helper Functions
def compute_exact_match(pred_start, pred_end, true_start, true_end):
    return (pred_start == true_start) and (pred_end == true_end)

def compute_f1(pred_start, pred_end, true_start, true_end):
    pred_set = set(range(pred_start, pred_end + 1))
    true_set = set(range(true_start, true_end + 1))
    intersection = pred_set & true_set
    if not pred_set or not true_set:
        return 1 if pred_set == true_set else 0
    precision = len(intersection) / len(pred_set)
    recall = len(intersection) / len(true_set)
    return 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0

print("Helper functions defined.")
# Out:
# Loaded test data from test_data.json. Total examples: 371
# Helper functions defined.

# %%
# Automatic Testing
all_predictions = []
all_ground_truths = []
span_metrics = {"exact_match": 0, "f1": 0}
total_span_examples = 0

for item in tqdm(test_data, desc="Testing"):
    question = item["question"]
    context = item["document"] if "document" in item else item["context"]

    if task_type == "yes_no":
        ground_truth = item["yes_no_answer"]
        inputs = tokenizer(
            question, context, return_tensors="pt", truncation=True, max_length=512, padding="longest"
        ).to(device)

        # Remove `token_type_ids` for DistilBERT compatibility
        if "token_type_ids" in inputs:
            del inputs["token_type_ids"]

        # Perform inference
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            probabilities = torch.softmax(logits, dim=-1)
            predicted_class = torch.argmax(probabilities, dim=-1).item()

        # Map predicted class to "YES" or "NO"
        predicted_answer = "YES" if predicted_class == 1 else "NO"
        all_predictions.append(predicted_answer)
        all_ground_truths.append(ground_truth)

    elif task_type in ["short_answer", "long_answer"]:
        true_start = item["start_token"]
        true_end = item["end_token"]
        tokenized = tokenizer(
            question, context, truncation=True, max_length=512, padding="max_length", return_tensors="pt", return_offsets_mapping=True
        ).to(device)

        input_ids = tokenized["input_ids"]
        attention_mask = tokenized["attention_mask"]
        offset_mapping = tokenized["offset_mapping"].squeeze(0).tolist()
        sep_index = input_ids.squeeze(0).tolist().index(tokenizer.sep_token_id) + 1
        char_start = len(" ".join(context.split()[:true_start])) + 1
        char_end = len(" ".join(context.split()[:true_end]))
        pred_start, pred_end = None, None

        for idx, (start_offset, end_offset) in enumerate(offset_mapping[sep_index:], start=sep_index):
            if start_offset <= char_start < end_offset:
                pred_start = idx
            if start_offset < char_end <= end_offset:
                pred_end = idx

        if pred_start is None or pred_end is None:
            continue

        # Perform inference
        with torch.no_grad():
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            start_logits = outputs.start_logits
            end_logits = outputs.end_logits
            model_start = torch.argmax(start_logits, dim=1).item()
            model_end = torch.argmax(end_logits, dim=1).item()

        # Compute metrics
        exact_match = compute_exact_match(model_start, model_end, pred_start, pred_end)
        f1 = compute_f1(model_start, model_end, pred_start, pred_end)
        span_metrics["exact_match"] += exact_match
        span_metrics["f1"] += f1
        total_span_examples += 1

print("Testing complete.")
# Out:
# Testing: 100%|██████████| 371/371 [00:01<00:00, 208.45it/s]
# Testing complete.

# %%
# Evaluation Metrics and Answer logs
if task_type == "yes_no":
    # Calculate metrics
    accuracy = accuracy_score(all_ground_truths, all_predictions)
    report = classification_report(all_ground_truths, all_predictions, target_names=["NO", "YES"])
    
    # Print overall metrics
    print(f"Overall Accuracy: {accuracy:.2f}")
    print("Classification Report:")
    print(report)

    # Print questions and answers
    print("\nQuestions and Answers:")
    for idx, item in enumerate(test_data):
        question = item["question"]
        ground_truth = item["yes_no_answer"]
        predicted_answer = all_predictions[idx]
        print(f"Q{idx + 1}: {question}")
        print(f"  Predicted Answer: {predicted_answer}")
        print(f"  Ground Truth: {ground_truth}")
        print("-" * 50)

elif task_type in ["short_answer", "long_answer"]:
    # Calculate metrics
    span_metrics["exact_match"] /= total_span_examples
    span_metrics["f1"] /= total_span_examples
    
    # Print span-based metrics
    print(f"Span-Based Validation Metrics:")
    print(f"  - Exact Match: {span_metrics['exact_match']:.4f}")
    print(f"  - F1 Score: {span_metrics['f1']:.4f}")

    # Print questions and answers
    print("\nQuestions and Answers:")
    for idx, item in enumerate(test_data):
        question = item["question"]
        context = item["document"] if "document" in item else item["context"]
        true_start = item["start_token"]
        true_end = item["end_token"]
        predicted_start = pred_start
        predicted_end = pred_end

        # Decode predicted and true spans
        predicted_span = " ".join(context.split()[predicted_start:predicted_end + 1]) if predicted_start and predicted_end else "N/A"
        true_span = " ".join(context.split()[true_start:true_end]) if true_start and true_end else "N/A"
        
        print(f"Q{idx + 1}: {question}")
        print(f"  Predicted Answer: {predicted_span}")
        print(f"  Ground Truth: {true_span}")
        print(f"  Predicted Span Indices: {model_start}-{model_end}")
        print(f"  True Span Indices: {pred_start}-{pred_end}")
        print(f"  Exact Match: {exact_match}")
        print(f"  F1 Score: {f1}")
        print("-" * 50)
# Out:
# Overall Accuracy: 0.54
# Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.63      0.34      0.44       197
#          YES       0.51      0.78      0.62       174
#
#     accuracy                           0.54       371
#    macro avg       0.57      0.56      0.53       371
# weighted avg       0.58      0.54      0.52       371
#
#
# Questions and Answers:
# Q1: does the dog die in evil dead remake
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q2: does st louis still have a football team
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q3: is puerto rico part of the continental usa
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q4: do i need a tourist visa for taiwan
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q5: is a city and guilds equivalent to a degree
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q6: if travelling at the speed of light would it take 1 million years to reach the andromeda galaxy
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q7: does jessica jones kill luke cage's wife
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q8: has minnesota ever voted for a republican president
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q9: does hugh grant sing in music and lyrics movie
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q10: is the 2005 ford focus front wheel drive
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q11: footnote 4 of united states v. carolene products co. identifies areas where
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q12: is pokemon mystery dungeon explorers of the sky the same as time and darkness
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q13: can you drive between north and south america
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q14: an induced magnetic field in a wire opposed the change in the external magnetic field
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q15: did they have gatling guns in the civil war
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q16: can brothers be deployed at the same time
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q17: is there going to be an ant man 2 movie
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q18: does there have to be a return address on an envelope
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q19: do you need a licence to play airsoft
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q20: do you get anything for 2 lucky stars on the euromillions
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q21: 99 of all is found inside the cells of the body
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q22: has there ever been a human chimp hybrid
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q23: did any romans survive the battle of teutoburg forest
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q24: do champions league losers go to europa league
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q25: is barney the purple dinosaur still on tv
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q26: is a german shepherd considered a wolf hybrid
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q27: can eustachian tube dysfunction cause shortness of breath
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q28: has an nfl team ever played a super bowl in their own stadium
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q29: chelsea vs man u penalty shootout champions league
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q30: cells are the basic unit of life and in all organisms
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q31: is extended release the same as time release
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q32: can 17 year olds be tried as adults
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q33: have the san diego padres ever won the world series
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q34: is this the last season of coke studio
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q35: do you get europa league for winning the efl cup
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q36: are you french if you are born in france
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q37: does us have free trade agreement with china
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q38: was cheryl blossom in the original archie comics
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q39: is bhartiya mahila bank a public sector bank
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q40: do second place winners on survivor get money
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q41: are the dark ages and middle ages the same
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q42: can you get a tattoo under 18 with parental consent in texas
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q43: the target hr zone is the range between 60 - 80 of an individual's maximum hr
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q44: does having a baby in australia give you citizenship
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q45: is puja the most important part of hinduism
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q46: has a hurrican ever hit the west coast
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q47: can the queen in chess move like a horse
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q48: are platypus the only mammals that lay eggs
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q49: was canada ever part of the british empire
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q50: does the lakers and clippers share a court
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q51: are the paralympic games the same as the special olympics world games
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q52: home and away does roo keep the baby
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q53: is there an airport in las cruces new mexico
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q54: is john wayne airport same as santa ana
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q55: does the wwe championship belt have real diamonds
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q56: is costa rica a part of the united states of america
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q57: several cranial nerves innervate structures of the tongue
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q58: was will and grace season 8 episode 1 live
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q59: state laws do not have to be approved by the federal government before they become effective
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q60: is avatar aang in the legend of korra
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q61: is the bugatti veyron the fastest car in the world
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q62: is ain't a word in the webster dictionary
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q63: is there an airport in prince albert saskatchewan
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q64: is this the last season of gsme of thrones
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q65: corporate governance is the system that directs and controls business corporations
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q66: is care first the same as blue cross blue shield
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q67: can u play playstation 2 games on ps3
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q68: do xbox 360 games work on the xbox one s
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q69: will there be another series of gavin and stacey
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q70: is amazon prime video part of amazon prime
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q71: has moscow always been the capital of russia
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q72: do you get conjugal visits in prison uk
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q73: is there a sequel to sign of the beaver
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q74: do i need a permit to open carry in georgia
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q75: do they still put the worm in tequila
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q76: was the first spiderman movie made by marvel
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q77: by the mid-1980s fox had emerged as a viable fourth network
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q78: the walking dead is season 8 the last season
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q79: do you have to show id to police in texas
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q80: the main component of stomach acid is sulfuric acid
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q81: has croatia ever won a world cup final
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q82: does lindsay lohan play the guitar in freaky friday
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q83: is there a marks and spencer in usa
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q84: can a us citizen travel to north korea
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q85: are brooklyn and queens part of long island
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q86: does the old apple remote work with new macbook pro
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q87: was columbia the first space shuttle to fly into space
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q88: do ac milan and inter milan share the same stadium
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q89: was the movie hook based on a book
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q90: are tui and thomas cook the same company
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q91: is president higher than prime minister in singapore
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q92: is washington dc one of the 50 states
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q93: did all us presidents go to ivy league schools
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q94: is rogue one an official star wars movie
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q95: is there a series 5 of sleepy hollow
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q96: can you restart a heart that has flatlined
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q97: was the marshall plan an example of containment
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q98: the walking dead do they ever find sophia
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q99: is the venom movie a part of the mcu
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q100: the boat that rocked is it a true story
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q101: do the dogs die in where the red fern grows 2
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q102: is british english the same as canadian english
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q103: is a deed of trust a security instrument
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q104: can you play nintendo ds games on ds lite
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q105: is there a walking dead season 3 game
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q106: do you have lymph nodes in your cheeks
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q107: my father is a canadian citizen can i become one
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q108: is hellmans mayo and best foods the same
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q109: was the waltons tv show based on a real family
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q110: are the yankees the only team without names
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q111: is there a way to find prime numbers
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q112: will there be a fifth season of mom
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q113: can you be sentenced to death in the uk
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q114: is the apollo victoria theatre in the west end
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q115: can you buy liquor in new york on sunday
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q116: do they find sophia on the walking dead
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q117: was the battle of fort sumter the first battle
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q118: is collision damage waiver the same as loss damage waiver
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q119: is there a cure for rift valley fever
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q120: is operation smile the same as smile train
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q121: is there a lift at angel tube station
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q122: is royal holloway classed as a london university
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q123: is my brothers wife my husbands sister in law
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q124: will there be a 5th series of rake
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q125: is there a tube station at wembley stadium
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q126: is there any crab in imitation crab meat
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q127: do you need a permit to burn a flag
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q128: will there ever be a sequel to i am number 4
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q129: did eminem win an oscar for 8 mile
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q130: is there a toll from oakland to san francisco
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q131: is there a marks and spencer in germany
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q132: in sq3r the 3 r's are in order review read recite
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q133: is the minor pentatonic scale the same as the blues scale
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q134: in cooprative banking the borrowers or members are banks
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q135: does a rook piercing go through the back of your ear
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q136: was michael gambon in the chamber of secrets
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q137: has belgium ever made it to the world cup final
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q138: is there a valve between the superior vena cava and the right atrium
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q139: do they still make chrysler town and country
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q140: can a founder of a trust be a beneficiary
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q141: is there a new series of the goldbergs
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q142: can a current vice president run for president
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q143: has polaris always been the north star also known as the pole star
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q144: will there be a my little pony season 8
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q145: does the boy die in the space between us
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q146: is time warner the same as time warner cable
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q147: is there another hunger games after mockingjay part 2
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q148: is the hyundai veloster turbo a sports car
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q149: was the us part of the league of nations
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q150: do eric and donna get back together in season 8
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q151: will they make a season 5 of degrassi
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q152: do the losers keep the money on tipping point
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q153: is the clark memorial bridge a toll bridge
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q154: is france a part of the united kingdom
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q155: do xbox 360 games work on the one
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q156: does mark watney die in the martian movie
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q157: in chess can a knight jump over two pieces
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q158: is blood c a sequel to blood plus
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q159: is josh dun still with twenty one pilots
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q160: did michael vick ever play a full season
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q161: india is the first country to reach mars
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q162: does the us vice president live in the white house
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q163: the highest point of the appalachian mountains is located at mt. mitchell in massachusetts
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q164: do you need a pistol permit to shoot at a range in ny
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q165: does buffy's mom know she's a slayer
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q166: are they making more seasons of criminal minds
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q167: are anthem and empire blue cross the same
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q168: do witnesses have the right to remain silent
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q169: is a rifle the same as a shotgun
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q170: do any states still use the firing squad
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q171: is sunny d and sunny delight the same thing
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q172: do all the states have daylight savings time
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q173: is simon the father of sandy's baby on 7th heaven
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q174: can you get psychosis from lack of sleep
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q175: do you need a tv licence in uk
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q176: is red lobster still a part of darden
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q177: has the un ever intervened in a conflict involving indonesia
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q178: was the movie deliverance based on a book
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q179: can some viruses change normal cells to tumor cells
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q180: will there be a adventures of tintin 2
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q181: the currency of all eu countries is the euro
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q182: does xbox one game work on xbox 360
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q183: does a self portrait have to be of you
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q184: is pokemon fire red the same as leaf green
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q185: did they ever show the gooch on different strokes
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q186: was there a railroad in the underground railroad
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q187: is irish music and celtic music the same
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q188: is the new macgyver the old macgyver's son
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q189: is porto rico a part of the united states
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q190: can you buy alcohol in sc on sunday
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q191: has a team won a superbowl at home
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q192: can you open carry a shotgun in ohio
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q193: is the cochlea part of the vestibular system
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q194: is the english channel part of the north sea
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q195: is there a difference between barbuda and barbados
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q196: is the movie hocus pocus based on a book
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q197: can a catholic receive communion in an episcopal church
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q198: does spiderman make his own web in the comics
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q199: is the sierra nevada part of the rocky mountains
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q200: does michael jackson sing on rockwell's somebody's watching me
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q201: has sanibel island ever been hit by a hurricane
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q202: are dollar general and dollar tree owned by the same company
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q203: can a game end in a tie in the nfl
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q204: is the global war on terrorism medal a campaign badge
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q205: is there going to be new episodes of fairy tail
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q206: did the actor who played freddy krueger die
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q207: is there a national drinking age in the us
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q208: is there a nuclear power plant in indiana
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q209: does a technical foul count as a personal foul in the nba
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q210: you can tell a lot about a person by how they treat their waiter
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q211: was the principle of self determination applied to areas outside of europe
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q212: is the blues brothers movie a true story
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q213: is season 3 the last season for jane the virgin
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q214: is timing belt and cam belt the same
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q215: is xbox 360 backwards compatible with xbox one
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q216: downton abbey will there be a season 7
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q217: are you allowed to carry a knife in canada
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q218: in the movie no escape do they survive
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q219: was czechoslovakia part of the league of nations
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q220: is there a bb&t bank in new jersey
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q221: does a 10 week old kitten need milk
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q222: is hawaii part of the north american continent
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q223: the bill of sale is absolute proof of ownership
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q224: are there red light cameras for left turns
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q225: will there be a season 2 for terra nova
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q226: do the rest of europe change their clocks
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q227: do away goals count in league one playoffs
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q228: did israel win any medals in the 2018 winter olympics
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q229: is oprah on every cover of o magazine
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q230: is there an in and out in pennsylvania
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q231: is latin america the same as central america
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q232: can you go out with a wild card in uno
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q233: is a dui a criminal offence in canada
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q234: is red velvet cake chocolate cake with red food coloring
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q235: what is the movie shawshank redemption based on a true story
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q236: if a table contains a primary key there can be no duplicate records in a table
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q237: does the maloof family own the sacramento kings
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q238: are the channel islands part of the eu
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q239: do you need a college degree to take the bar exam
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q240: does fred come back in drop dead diva season 4
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q241: was the alamo part of the mexican american war
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q242: does every player get a super bowl trophy
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q243: the presence of vestigial structures is explained by the common descent hypothesis. true false
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q244: is popeye the sailor man a disney character
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q245: is puerto rico part of the united states territory
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q246: has a 16 seed ever won a ncaa tournament game
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q247: cristiano ronaldo has he won a world cup
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q248: does the island of puerto rico pay federal income tax
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q249: jab harry met sejal a copy of when harry met sally
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q250: the heart of the sea is it a true story
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q251: diplomatic immunity for consular officers is not absolute quizlet
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q252: bermuda is an island in the caribbean sea
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q253: does better call saul take place after breaking bad
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q254: does sweeney todd know johanna is his daughter
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q255: are the claws on the scorpion considered to be walking legs
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q256: is there a town called gravity falls in oregon
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q257: is greenland on the continent of north america
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q258: you're the one that i want reunion
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q259: is there a follow up movie to i am number four
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q260: has anyone ever tied for an olympic medal
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q261: are they making a seventh season of once upon a time
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q262: is there a difference between 9x19 and 9mm luger
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q263: is the us treasury part of the federal reserve
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q264: is there a cat in the wizard of oz
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q265: is an american billion the same as a british billion
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q266: michael owen world player of the year 2001
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q267: was the movie dreamgirls based on the supremes
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q268: is windows defender an antivirus in windows 7
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q269: does jason’s wife die on seal team
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q270: were there helicopters in the second world war
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q271: does france have a president and prime minister
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q272: is there compulsory military service in the us
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q273: did the colour orange come before the fruit
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q274: does a novena end on the feast day
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q275: is the queen's birthday a public holiday in england
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q276: did the crittenden resolution define the war aims of the north
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q277: has there ever been a host team in the super bowl
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q278: does jj die in criminal minds season 9
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q279: do us residents need a visa to go to colombia
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q280: intelenet global services pvt ltd - a serco company
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q281: amazon's data warehousing service is called redshift
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q282: did heath ledger win an oscar for joker
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q283: are all the songs from mamma mia by abba
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q284: is there a cut at the british open
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q285: a positron is the antiparticle of the electron
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q286: is egypt in african cup of nations 2018
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q287: is there a book 14 in the series of unfortunate events
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q288: is there going to be a season 13 for criminal minds
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q289: does winning the fa cup qualify you for the champions league
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q290: is there a taco bell in mexico city
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q291: is america the only country with a drinking age of 21
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q292: is 10 cloverfield lane a prequel to cloverfield
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q293: can you step over the free throw line
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q294: can the president make an executive order without congress
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q295: can you play infamous second son on ps3
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q296: the martian does he die at the end
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q297: is wisconsin part of the interstate driver's license compact
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q298: are miami and miami beach the same city
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q299: three billboards outside ebbing missouri is a real story
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q300: is it legal to have a radar detector in texas
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q301: is the big dipper the same as the plough
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q302: can u play xbox 360 games on an xbox 1
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q303: is let me in the same as let the right one in
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q304: does george ever come back to grey's anatomy
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q305: are the sierra nevadas part of the rockies
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q306: do you have to carry your draft card
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q307: are the new york cosmos in the mls
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q308: are navy beans and kidney beans the same
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q309: did they really ride motorcycles in wild hogs
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q310: does a run in gin rummy have to be the same suit
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q311: was france a republic after the french revolution
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q312: did we leave the lunar rover on the moon
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q313: the former soviet union broke into separate states
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q314: has there ever been a switch pitcher in major league baseball
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q315: can light reactions take place in the dark
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q316: can an enrolled agent represent a taxpayer in tax court
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q317: is season 9 the last season of adventure time
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q318: is yonge street the longest street in the world
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q319: did kate winslet win an oscar for titanic
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q320: man on fire is it based on a true story
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q321: can a king castle after being in check
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q322: is all of rick and morty season 3 out
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q323: sequence occurs when pattern of notes is repeated
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q324: are michael and lincoln brothers in real life
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q325: is puerto rico the same as dominican republic
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q326: you play xbox 360 games on xbox one
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q327: can my remington 1100 shoot 3 inch shells
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q328: does the icc has jurisdiction in the united states
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q329: death in paradise do camille and humphrey get together
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q330: does a us citizen need a visa to go to south korea
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q331: is there a season 4 last tango in halifax
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q332: is fashion institute of technology a suny school
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q333: did lauren bacall sing in to have and to have not
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q334: is the annihilation movie just the first book
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q335: can i refuse to give id to police
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q336: was there ever a female prime minister in canada
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q337: are there sea turtles in the pacific ocean
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q338: is there a difference between cougars and mountain lions
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q339: is la rambla the same as las ramblas
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q340: is puerto rico a united states of america state
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q341: is the song stand by me a gospel song
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q342: do banks in the us have iban numbers
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q343: are liquor stores open on sunday in wv
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q344: is it illegal to not turn up to work
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q345: is jeep grand cherokee a full size suv
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q346: can a us citizen hold a foreign title
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q347: has the host country ever won world cup
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q348: is the mall of america the biggest mall in the united states
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q349: is the show vinyl based on a true story
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q350: is the dodge stealth the same as the mitsubishi 3000gt
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q351: can you use hyper v on windows 7
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q352: are the queen of hearts and the red queen the same person
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q353: have any uk prime ministers died in office
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q354: is there another series of law and order uk
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q355: is a mule a donkey and a horse
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q356: is trelane a member of the q continuum
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q357: can tourists go to gun ranges in usa
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q358: is china the third largest country in population
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q359: is the profunda femoral vein a deep vein
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q360: did bolivia make it to the world cup
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q361: is all of australia on the same time zone
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q362: do they ever show sheridan on keeping up appearances
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q363: do british citizens need an eta for australia
#   Predicted Answer: NO
#   Ground Truth: YES
# --------------------------------------------------
# Q364: is there going to be a now you see me 3
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q365: are ant man and giant man the same
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q366: is there a line between the pacific and atlantic ocean
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q367: is the pink dog in blues clues a boy
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q368: are the oscars the same as golden globes
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------
# Q369: is mississauga part of the greater toronto area
#   Predicted Answer: YES
#   Ground Truth: YES
# --------------------------------------------------
# Q370: does the tesla model s have a gas engine
#   Predicted Answer: NO
#   Ground Truth: NO
# --------------------------------------------------
# Q371: can a canadian passport be used as proof of citizenship
#   Predicted Answer: YES
#   Ground Truth: NO
# --------------------------------------------------

# %% [markdown]
# Manual Testing for each qa

# %%
def test_yes_no_question(question, context, model, tokenizer, device):
    # Tokenize the input
    inputs = tokenizer(
        question,
        context,
        return_tensors="pt",
        truncation=True,
        max_length=512,
        padding="longest"
    ).to(device)

    # Remove `token_type_ids` for DistilBERT (if necessary)
    if "token_type_ids" in inputs:
        del inputs["token_type_ids"]

    # Perform inference
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        probabilities = torch.softmax(logits, dim=-1)
        predicted_class = torch.argmax(probabilities, dim=-1).item()

    # Map prediction to "YES" or "NO"
    predicted_answer = "YES" if predicted_class == 1 else "NO"

    # Print the results
    print(f"Question: {question}")
    print(f"Context: {context}")
    print(f"Predicted Answer: {predicted_answer}")
    print(f"Confidence: {probabilities[0][predicted_class]:.4f}")

# %%
# Define a question and context
question = "Is the capital of France Paris?"
context = "Paris is the capital of France, known for its rich culture and history."

# Call the function to test
test_yes_no_question(question, context, model, tokenizer, device)
# Out:
# Question: Is the capital of France Paris?
# Context: Paris is the capital of France, known for its rich culture and history.
# Predicted Answer: YES
# Confidence: 0.9507

# %%
def test_short_answer_question(question, context, model, tokenizer, device):
    # Tokenize the input
    inputs = tokenizer(
        question,
        context,
        return_tensors="pt",
        truncation=True,
        max_length=512,
        padding="max_length",
        return_offsets_mapping=True 
    ).to(device)

    # Forward pass through the model
    with torch.no_grad():
        outputs = model(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"]
        )

    # Extract start and end logits
    start_logits = outputs.start_logits
    end_logits = outputs.end_logits

    # Get the most probable start and end tokens
    start_idx = torch.argmax(start_logits, dim=1).item()
    end_idx = torch.argmax(end_logits, dim=1).item()

    # Convert token indices back to the text
    input_ids = inputs["input_ids"].squeeze(0)
    offset_mapping = inputs["offset_mapping"].squeeze(0).tolist()

    # Ensure indices are within bounds and valid
    if start_idx >= len(offset_mapping) or end_idx >= len(offset_mapping):
        return {"error": "Predicted indices are out of bounds."}

    # Map token indices to character spans in the context
    start_char, end_char = offset_mapping[start_idx][0], offset_mapping[end_idx][1]

    # Extract the answer from the context
    predicted_answer = context[start_char:end_char]

    return {
        "question": question,
        "context": context,
        "predicted_answer": predicted_answer,
        "start_idx": start_idx,
        "end_idx": end_idx,
        "start_char": start_char,
        "end_char": end_char
    }

# %%
# Give a short-answer question and context
question = "What is the capital of France?"
context = ("France is a country in Western Europe. Its capital city is Paris, known for its art, gastronomy, and culture. The Eiffel Tower and the Louvre Museum are among its iconic landmarks.")

result = test_short_answer_question(question, context, model, tokenizer, device)

if "error" in result:
    print(result["error"])
else:
    print(f"Question: {result['question']}")
    print(f"Predicted Answer: {result['predicted_answer']}")
    print(f"Start Token: {result['start_idx']}, End Token: {result['end_idx']}")
    print(f"Answer Span (Character Indices): {result['start_char']} - {result['end_char']}")
# Out:
# Question: What are the key features of the Amazon rainforest?
# Predicted Answer: a
# Start Token: 10, End Token: 10
# Answer Span (Character Indices): 50 - 51

# %%
def test_long_answer_question(question, context, model, tokenizer, device):
    inputs = tokenizer(
        question,
        context,
        return_tensors="pt",
        truncation=True,
        max_length=512,
        padding="max_length",
        return_offsets_mapping=True
    ).to(device)

    with torch.no_grad():
        outputs = model(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"]
        )

    start_logits = outputs.start_logits
    end_logits = outputs.end_logits

    start_idx = torch.argmax(start_logits, dim=1).item()
    end_idx = torch.argmax(end_logits, dim=1).item()

    # Debugging outputs
    print(f"Start Index: {start_idx}, End Index: {end_idx}")
    offset_mapping = inputs["offset_mapping"].squeeze(0).tolist()

    # Check if indices are valid
    if start_idx >= len(offset_mapping) or end_idx >= len(offset_mapping):
        return {"error": "Predicted indices are out of bounds."}

    start_char, end_char = offset_mapping[start_idx][0], offset_mapping[end_idx][1]

    # Handle invalid spans
    if start_char > end_char:
        print("Invalid span detected. Adjusting end index.")
        end_char = start_char + 10 

    predicted_answer = context[start_char:end_char]
    return {
        "question": question,
        "context": context,
        "predicted_answer": predicted_answer,
        "start_idx": start_idx,
        "end_idx": end_idx,
        "start_char": start_char,
        "end_char": end_char
    }

# %%
# Define a long-answer question and context
question: "How does photosynthesis work in plants?"
context: "Photosynthesis is a vital process for life on Earth, enabling plants to convert sunlight into energy. It is closely linked to the carbon cycle. <p>Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy, usually from the sun, into chemical energy in the form of glucose. This process takes place in the chloroplasts of plant cells, where chlorophyll captures sunlight. During photosynthesis, carbon dioxide from the air and water from the soil react in the presence of sunlight to produce glucose and oxygen.</p> Plants also produce oxygen as a byproduct, which supports life on Earth."

result = test_long_answer_question(question, context, model, tokenizer, device)

# Print the result
if "error" in result:
    print(result["error"])
else:
    print(f"Question: {result['question']}")
    print(f"Predicted Long Answer: {result['predicted_answer']}")
    print(f"Start Token: {result['start_idx']}, End Token: {result['end_idx']}")
    print(f"Answer Span (Character Indices): {result['start_char']} - {result['end_char']}")
# Out:
# Start Index: 46, End Index: 124
# Question: What are the key features of the Amazon rainforest?
# Predicted Long Answer: <p>The Amazon rainforest, also known as Amazonia, is a vast tropical rainforest in South America that covers over 5.5 million square kilometers. It is known for its incredible biodiversity, hosting millions of species of plants, animals, and insects. The Amazon River, one of the largest rivers in the world, runs through the forest, contributing to the rich ecosystem.</p>
# Start Token: 46, End Token: 124
# Answer Span (Character Indices): 179 - 552
